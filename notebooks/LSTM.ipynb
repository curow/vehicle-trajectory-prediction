# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

import numpy as np
import random
import time
import os

import sys
sys.path.append("..")
from data import get_dataset # custom helper function to get dataset
from models.Seq2Seq import Seq2Seq, Encoder, Decoder

# %%
BATCH_SIZE = 256

# %%
class WrappedDataLoader:
    def __init__(self, dataloader, func):
        self.dataloader = dataloader
        self.func = func
        
    def __len__(self):
        return len(self.dataloader)
    
    def __iter__(self):
        iter_dataloader = iter(self.dataloader)
        for batch in iter_dataloader:
            yield self.func(*batch)
            
def preprocess(x, y):
    # x and y is [batch size, seq len, feature size]
    # to make them work with default assumption of LSTM,
    # here we transpose the first and second dimension
    # return size = [seq len, batch size, feature size]
    return x.transpose(0, 1), y.transpose(0, 1)

# %%
train_data, val_data, test_data = get_dataset(["train", "val", "test"])
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True, num_workers=6)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE * 2, shuffle=False, num_workers=6)

train_loader = WrappedDataLoader(train_loader, preprocess)
val_loader = WrappedDataLoader(val_loader, preprocess)
print(len(train_loader))
print(len(val_loader))
# Out:
# 805
# 78

# %%
dev = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
for x, y in train_loader:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([20, 256, 2])
# torch.Size([30, 256, 2])

# %%
INPUT_DIM = 2
OUTPUT_DIM = 2
ENC_EMB_DIM = 128
DEC_EMB_DIM = 128
HID_DIM = 256
N_LAYERS = 4
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)

model = Seq2Seq(enc, dec, dev).to(dev)

# %%
model
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (linear): Linear(in_features=2, out_features=128, bias=True)
#     (rnn): LSTM(128, 256, num_layers=4, dropout=0.5)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (embedding): Linear(in_features=2, out_features=128, bias=True)
#     (rnn): LSTM(128, 256, num_layers=4, dropout=0.5)
#     (linear): Linear(in_features=256, out_features=2, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 3,949,826 trainable parameters

# %%
optimizer = optim.Adam(model.parameters())
criterion = nn.MSELoss()

# %%
def train(model, dataloader, optimizer, criterion):
    model.train()
    epoch_loss = 0
    for i, (x, y) in enumerate(dataloader):
        # put data into GPU
        x = x.to(dev)
        y = y.to(dev)
        
        # zero all param gradients
        optimizer.zero_grad()
        
        # run seq2seq to get predictions
        y_pred = model(x, y)
        
        # get loss and compute model trainable params gradients though backpropagation
        loss = criterion(y_pred, y)
        loss.backward()
        
        # update model params
        optimizer.step()
        
        # add batch loss, since loss is single item tensor
        # we can get its value by loss.item()
        epoch_loss += loss.item()
    return epoch_loss / len(dataloader)

# %%
def evaluate(model, dataloader, criterion):
    model.eval()
    epoch_loss = 0
    with torch.no_grad():
        for i, (x, y) in enumerate(dataloader):
            x = x.to(dev)
            y = y.to(dev)
            
            # turn off teacher forcing
            y_pred = model(x, y, teacher_forcing_ratio = 0)
            
            loss = criterion(y_pred, y)
            epoch_loss += loss.item()
    return epoch_loss / len(dataloader)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import os
N_EPOCHES = 100
best_val_loss = float('inf')

# load previous best model params if exists
model_dir = "saved_models/Seq2Seq"
saved_model_path = model_dir + "/best_seq2seq.pt"
if os.path.isfile(saved_model_path):
    model.load_state_dict(torch.load(saved_model_path))
    print("successfully load previous best model parameters")
    
for epoch in range(N_EPOCHES):
    start_time = time.time()
    
    train_loss = train(model, train_loader, optimizer, criterion)
    val_loss = evaluate(model, val_loader, criterion)
    
    end_time = time.time()
    
    mins, secs = epoch_time(start_time, end_time)
    
    print(F'Epoch: {epoch+1:02} | Time: {mins}m {secs}s')
    print(F'\tTrain Loss: {train_loss:.3f}')
    print(F'\t Val. Loss: {val_loss:.3f}')

    if val_loss < best_val_loss:
        os.makedirs(model_dir, exist_ok=True)
        torch.save(model.state_dict(), saved_model_path)
# Out:
# successfully load previous best model parameters
# Epoch: 01 | Time: 3m 2s
# 	Train Loss: 992.792
# 	 Val. Loss: 77019.468
# Epoch: 02 | Time: 2m 58s
# 	Train Loss: 821.853
# 	 Val. Loss: 77375.103
# Epoch: 03 | Time: 2m 57s
# 	Train Loss: 1047.724
# 	 Val. Loss: 89241.402
# Epoch: 04 | Time: 2m 57s
# 	Train Loss: 1352.522
# 	 Val. Loss: 77503.924
# Epoch: 05 | Time: 2m 57s
# 	Train Loss: 1286.191
# 	 Val. Loss: 73347.698
# Epoch: 06 | Time: 2m 57s
# 	Train Loss: 1182.214
# 	 Val. Loss: 70612.481
# Epoch: 07 | Time: 2m 57s
# 	Train Loss: 971.504
# 	 Val. Loss: 73029.150
# Epoch: 08 | Time: 2m 57s
# 	Train Loss: 997.860
# 	 Val. Loss: 74489.668
# Epoch: 09 | Time: 2m 57s
# 	Train Loss: 913.328
# 	 Val. Loss: 87567.333
# Epoch: 10 | Time: 2m 57s
# 	Train Loss: 964.778
# 	 Val. Loss: 90857.000
# Epoch: 11 | Time: 2m 57s
# 	Train Loss: 1011.006
# 	 Val. Loss: 79313.151
# Epoch: 12 | Time: 2m 57s
# 	Train Loss: 848.750
# 	 Val. Loss: 81694.568
# Epoch: 13 | Time: 2m 57s
# 	Train Loss: 943.379
# 	 Val. Loss: 83552.797
# Epoch: 14 | Time: 2m 58s
# 	Train Loss: 959.676
# 	 Val. Loss: 77295.998
# Epoch: 15 | Time: 2m 57s
# 	Train Loss: 1117.397
# 	 Val. Loss: 85162.054
# Epoch: 16 | Time: 2m 57s
# 	Train Loss: 913.064
# 	 Val. Loss: 84732.248
# Epoch: 17 | Time: 2m 57s
# 	Train Loss: 1061.847
# 	 Val. Loss: 87834.878
# Epoch: 18 | Time: 2m 57s
# 	Train Loss: 1031.056
# 	 Val. Loss: 88285.773
# Epoch: 19 | Time: 2m 57s
# 	Train Loss: 2192.626
# 	 Val. Loss: 138255.987
# Epoch: 20 | Time: 2m 57s
# 	Train Loss: 1914.528
# 	 Val. Loss: 76674.147
# Epoch: 21 | Time: 2m 57s
# 	Train Loss: 1549.320
# 	 Val. Loss: 84453.876
# Epoch: 22 | Time: 2m 57s
# 	Train Loss: 1168.763
# 	 Val. Loss: 79845.083
# Epoch: 23 | Time: 2m 57s
# 	Train Loss: 1595.112
# 	 Val. Loss: 85624.758
# Epoch: 24 | Time: 2m 57s
# 	Train Loss: 1216.751
# 	 Val. Loss: 73269.656
# Epoch: 25 | Time: 2m 57s
# 	Train Loss: 1410.850
# 	 Val. Loss: 67456.550
# Epoch: 26 | Time: 2m 57s
# 	Train Loss: 1360.529
# 	 Val. Loss: 70095.993
# Epoch: 27 | Time: 2m 57s
# 	Train Loss: 1505.448
# 	 Val. Loss: 121782.937
# Epoch: 28 | Time: 2m 57s
# 	Train Loss: 1341.887
# 	 Val. Loss: 79253.573
# Epoch: 29 | Time: 2m 57s
# 	Train Loss: 1352.848
# 	 Val. Loss: 75827.595
# Epoch: 30 | Time: 2m 57s
# 	Train Loss: 1127.707
# 	 Val. Loss: 76235.776
# Epoch: 31 | Time: 2m 57s
# 	Train Loss: 1244.069
# 	 Val. Loss: 77949.410
# Epoch: 32 | Time: 2m 57s
# 	Train Loss: 983.222
# 	 Val. Loss: 98793.383
# Epoch: 33 | Time: 2m 57s
# 	Train Loss: 1894.589
# 	 Val. Loss: 937250.526
# Epoch: 34 | Time: 2m 57s
# 	Train Loss: 1645.572
# 	 Val. Loss: 347724.624
# Epoch: 35 | Time: 2m 57s
# 	Train Loss: 1279.225
# 	 Val. Loss: 307532.001
# Epoch: 36 | Time: 2m 57s
# 	Train Loss: 1185.452
# 	 Val. Loss: 305108.654
# Epoch: 37 | Time: 2m 57s
# 	Train Loss: 1452.047
# 	 Val. Loss: 116910.984
# Epoch: 38 | Time: 2m 57s
# 	Train Loss: 1886.901
# 	 Val. Loss: 132329.189
# Epoch: 39 | Time: 2m 57s
# 	Train Loss: 1886.979
# 	 Val. Loss: 89933.062
# Epoch: 40 | Time: 2m 57s
# 	Train Loss: 1227.515
# 	 Val. Loss: 96134.287
# Epoch: 41 | Time: 2m 57s
# 	Train Loss: 1144.658
# 	 Val. Loss: 92787.825
# Epoch: 42 | Time: 2m 56s
# 	Train Loss: 1201.045
# 	 Val. Loss: 84977.312
# Epoch: 43 | Time: 2m 57s
# 	Train Loss: 1382.092
# 	 Val. Loss: 266392.560
# Epoch: 44 | Time: 2m 57s
# 	Train Loss: 2526.499
# 	 Val. Loss: 97176.764
# Epoch: 45 | Time: 2m 57s
# 	Train Loss: 1552.462
# 	 Val. Loss: 91642.034
# Epoch: 46 | Time: 2m 57s
# 	Train Loss: 2245.593
# 	 Val. Loss: 105028.271
# Epoch: 47 | Time: 2m 57s
# 	Train Loss: 1704.350
# 	 Val. Loss: 104932.157
# Epoch: 48 | Time: 2m 57s
# 	Train Loss: 1332.958
# 	 Val. Loss: 78108.687
# Epoch: 49 | Time: 2m 57s
# 	Train Loss: 1181.738
# 	 Val. Loss: 82633.760
# Epoch: 50 | Time: 2m 57s
# 	Train Loss: 1060.266
# 	 Val. Loss: 72875.570
# Epoch: 51 | Time: 2m 57s
# 	Train Loss: 1176.082
# 	 Val. Loss: 73254.889
# Epoch: 52 | Time: 2m 57s
# 	Train Loss: 1120.325
# 	 Val. Loss: 70083.545
# Epoch: 53 | Time: 2m 57s
# 	Train Loss: 1034.649
# 	 Val. Loss: 73546.349
# Epoch: 54 | Time: 2m 57s
# 	Train Loss: 1040.566
# 	 Val. Loss: 72454.259
# Epoch: 55 | Time: 2m 57s
# 	Train Loss: 1312.242
# 	 Val. Loss: 71995.040
# Epoch: 56 | Time: 2m 57s
# 	Train Loss: 1113.852
# 	 Val. Loss: 73053.150
# Epoch: 57 | Time: 2m 57s
# 	Train Loss: 1107.590
# 	 Val. Loss: 75244.698
# Epoch: 58 | Time: 2m 57s
# 	Train Loss: 972.358
# 	 Val. Loss: 77103.790
# Epoch: 59 | Time: 2m 57s
# 	Train Loss: 1554.207
# 	 Val. Loss: 99970.274
# Epoch: 60 | Time: 2m 57s
# 	Train Loss: 1104.212
# 	 Val. Loss: 97715.980
# Epoch: 61 | Time: 2m 57s
# 	Train Loss: 2603.854
# 	 Val. Loss: 76380.175
# Epoch: 62 | Time: 2m 57s
# 	Train Loss: 1220.144
# 	 Val. Loss: 75939.647
# Epoch: 63 | Time: 2m 57s
# 	Train Loss: 1369.116
# 	 Val. Loss: 78264.455
# Epoch: 64 | Time: 2m 57s
# 	Train Loss: 1443.277
# 	 Val. Loss: 73474.735
# Epoch: 65 | Time: 2m 57s
# 	Train Loss: 1247.226
# 	 Val. Loss: 74520.206
# Epoch: 66 | Time: 2m 57s
# 	Train Loss: 994.205
# 	 Val. Loss: 73652.783
# Epoch: 67 | Time: 2m 57s
# 	Train Loss: 1159.474
# 	 Val. Loss: 75164.079
# Epoch: 68 | Time: 2m 57s
# 	Train Loss: 962.505
# 	 Val. Loss: 74110.443
# Epoch: 69 | Time: 2m 57s
# 	Train Loss: 1207.423
# 	 Val. Loss: 80832.058
# Epoch: 70 | Time: 2m 56s
# 	Train Loss: 1829.459
# 	 Val. Loss: 70215.369
# Epoch: 71 | Time: 2m 56s
# 	Train Loss: 1301.060
# 	 Val. Loss: 71300.939
# Epoch: 72 | Time: 2m 57s
# 	Train Loss: 1099.379
# 	 Val. Loss: 70902.081
# Epoch: 73 | Time: 2m 56s
# 	Train Loss: 1888.738
# 	 Val. Loss: 61600.572
# Epoch: 74 | Time: 2m 57s
# 	Train Loss: 1298.482
# 	 Val. Loss: 65279.847
# Epoch: 75 | Time: 2m 57s
# 	Train Loss: 1081.920
# 	 Val. Loss: 69284.128
# Epoch: 76 | Time: 2m 57s
# 	Train Loss: 1792.405
# 	 Val. Loss: 66354.774
# Epoch: 77 | Time: 2m 57s
# 	Train Loss: 1478.786
# 	 Val. Loss: 67735.162
# Epoch: 78 | Time: 2m 57s
# 	Train Loss: 1223.367
# 	 Val. Loss: 68958.122
# Epoch: 79 | Time: 2m 57s
# 	Train Loss: 1084.659
# 	 Val. Loss: 73054.727
# Epoch: 80 | Time: 2m 57s
# 	Train Loss: 1675.037
# 	 Val. Loss: 110163.551
# Epoch: 81 | Time: 2m 57s
# 	Train Loss: 1763.002
# 	 Val. Loss: 132816.818
# Epoch: 82 | Time: 2m 57s
# 	Train Loss: 1662.751
# 	 Val. Loss: 99911.978
# Epoch: 83 | Time: 2m 57s
# 	Train Loss: 1627.672
# 	 Val. Loss: 85713.422
# Epoch: 84 | Time: 2m 57s
# 	Train Loss: 1241.051
# 	 Val. Loss: 77111.945
# Epoch: 85 | Time: 2m 57s
# 	Train Loss: 1113.057
# 	 Val. Loss: 75368.559
# Epoch: 86 | Time: 2m 58s
# 	Train Loss: 1348.079
# 	 Val. Loss: 71762.162
# Epoch: 87 | Time: 2m 57s
# 	Train Loss: 2404.429
# 	 Val. Loss: 74980.546
# Epoch: 88 | Time: 2m 56s
# 	Train Loss: 1902.000
# 	 Val. Loss: 77694.152
# Epoch: 89 | Time: 2m 56s
# 	Train Loss: 1511.124
# 	 Val. Loss: 74490.195
# Epoch: 90 | Time: 2m 57s
# 	Train Loss: 1439.806
# 	 Val. Loss: 72556.644
# Epoch: 91 | Time: 2m 56s
# 	Train Loss: 1260.230
# 	 Val. Loss: 72977.155
# Epoch: 92 | Time: 2m 57s
# 	Train Loss: 1357.072
# 	 Val. Loss: 75621.506
# Epoch: 93 | Time: 2m 56s
# 	Train Loss: 1216.431
# 	 Val. Loss: 74893.121
# Epoch: 94 | Time: 2m 56s
# 	Train Loss: 1705.665
# 	 Val. Loss: 87833.901
# Epoch: 95 | Time: 2m 56s
# 	Train Loss: 1797.544
# 	 Val. Loss: 84928.374
# Epoch: 96 | Time: 2m 57s
# 	Train Loss: 1319.547
# 	 Val. Loss: 83938.574
# Epoch: 97 | Time: 2m 56s
# 	Train Loss: 1337.802
# 	 Val. Loss: 83666.477
# Epoch: 98 | Time: 2m 56s
# 	Train Loss: 1190.042
# 	 Val. Loss: 78191.331
# Epoch: 99 | Time: 2m 56s
# 	Train Loss: 1239.785
# 	 Val. Loss: 75565.211
# Epoch: 100 | Time: 2m 56s
# 	Train Loss: 1058.159
# 	 Val. Loss: 75949.429
