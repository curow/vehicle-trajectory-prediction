# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

import numpy as np
import random
import time
import os

import sys
sys.path.append("..")
from data import get_dataset # custom helper function to get dataset
from models.Seq2Seq import Seq2Seq, Encoder, Decoder

# %%
BATCH_SIZE = 256

# %%
class WrappedDataLoader:
    def __init__(self, dataloader, func):
        self.dataloader = dataloader
        self.func = func
        
    def __len__(self):
        return len(self.dataloader)
    
    def __iter__(self):
        iter_dataloader = iter(self.dataloader)
        for batch in iter_dataloader:
            yield self.func(*batch)
            
def preprocess(x, y):
    # x and y is [batch size, seq len, feature size]
    # to make them work with default assumption of LSTM,
    # here we transpose the first and second dimension
    # return size = [seq len, batch size, feature size]
    return x.transpose(0, 1), y.transpose(0, 1)

# %%
train_data, val_data, test_data = get_dataset(["train", "val", "test"])
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True, num_workers=6)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE * 2, shuffle=False, num_workers=6)

train_loader = WrappedDataLoader(train_loader, preprocess)
val_loader = WrappedDataLoader(val_loader, preprocess)
print(len(train_loader))
print(len(val_loader))
# Out:
# 805
# 78

# %%
dev = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
for x, y in train_loader:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([20, 256, 2])
# torch.Size([30, 256, 2])

# %%
INPUT_DIM = 2
OUTPUT_DIM = 2
ENC_EMB_DIM = 128
DEC_EMB_DIM = 128
HID_DIM = 256
N_LAYERS = 4
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)

model = Seq2Seq(enc, dec, dev).to(dev)

# %%
model
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (linear): Linear(in_features=2, out_features=128, bias=True)
#     (rnn): LSTM(128, 256, num_layers=4, dropout=0.5)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (embedding): Linear(in_features=2, out_features=128, bias=True)
#     (rnn): LSTM(128, 256, num_layers=4, dropout=0.5)
#     (linear): Linear(in_features=256, out_features=2, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 3,949,826 trainable parameters

# %%
optimizer = optim.Adam(model.parameters())
criterion = nn.MSELoss()

# %%
def train(model, dataloader, optimizer, criterion):
    model.train()
    epoch_loss = 0
    for i, (x, y) in enumerate(dataloader):
        # put data into GPU
        x = x.to(dev)
        y = y.to(dev)
        
        # zero all param gradients
        optimizer.zero_grad()
        
        # run seq2seq to get predictions
        y_pred = model(x, y)
        
        # get loss and compute model trainable params gradients though backpropagation
        loss = criterion(y_pred, y)
        loss.backward()
        
        # update model params
        optimizer.step()
        
        # add batch loss, since loss is single item tensor
        # we can get its value by loss.item()
        epoch_loss += loss.item()
    return epoch_loss / len(dataloader)

# %%
def evaluate(model, dataloader, criterion):
    model.eval()
    epoch_loss = 0
    with torch.no_grad():
        for i, (x, y) in enumerate(dataloader):
            x = x.to(dev)
            y = y.to(dev)
            
            # turn off teacher forcing
            y_pred = model(x, y, teacher_forcing_ratio = 0)
            
            loss = criterion(y_pred, y)
            epoch_loss += loss.item()
    return epoch_loss / len(dataloader)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import os
N_EPOCHES = 100
best_val_loss = float('inf')

# load previous best model params if exists
model_dir = "saved_models/Seq2Seq"
saved_model_path = model_dir + "/best_seq2seq.pt"
if os.path.isfile(saved_model_path):
    model.load_state_dict(torch.load(saved_model_path))
    print("successfully load previous best model parameters")
    
for epoch in range(N_EPOCHES):
    start_time = time.time()
    
    train_loss = train(model, train_loader, optimizer, criterion)
    val_loss = evaluate(model, val_loader, criterion)
    
    end_time = time.time()
    
    mins, secs = epoch_time(start_time, end_time)
    
    print(F'Epoch: {epoch+1:02} | Time: {mins}m {secs}s')
    print(F'\tTrain Loss: {train_loss:.3f}')
    print(F'\t Val. Loss: {val_loss:.3f}')

    if val_loss < best_val_loss:
        os.makedirs(model_dir, exist_ok=True)
        torch.save(model.state_dict(), saved_model_path)
# Out:
# successfully load previous best model parameters
# Epoch: 01 | Time: 2m 56s
# 	Train Loss: 1427.647
# 	 Val. Loss: 74279.526
# Epoch: 02 | Time: 2m 56s
# 	Train Loss: 1445.820
# 	 Val. Loss: 73233.181
# Epoch: 03 | Time: 2m 56s
# 	Train Loss: 1705.407
# 	 Val. Loss: 74202.339
# Epoch: 04 | Time: 2m 57s
# 	Train Loss: 1368.853
# 	 Val. Loss: 77637.500
# Epoch: 05 | Time: 2m 56s
# 	Train Loss: 1210.794
# 	 Val. Loss: 72944.235
# Epoch: 06 | Time: 2m 57s
# 	Train Loss: 1437.476
# 	 Val. Loss: 72985.456
# Epoch: 07 | Time: 2m 57s
# 	Train Loss: 1182.040
# 	 Val. Loss: 74800.764
# Epoch: 08 | Time: 2m 56s
# 	Train Loss: 1551.511
# 	 Val. Loss: 82169.059
# Epoch: 09 | Time: 2m 57s
# 	Train Loss: 1236.219
# 	 Val. Loss: 77192.949
# Epoch: 10 | Time: 2m 56s
# 	Train Loss: 1140.388
# 	 Val. Loss: 73556.246
# Epoch: 11 | Time: 2m 56s
# 	Train Loss: 1132.512
# 	 Val. Loss: 73610.524
# Epoch: 12 | Time: 2m 56s
# 	Train Loss: 1220.219
# 	 Val. Loss: 73115.513
# Epoch: 13 | Time: 2m 56s
# 	Train Loss: 1110.304
# 	 Val. Loss: 73561.132
# Epoch: 14 | Time: 2m 56s
# 	Train Loss: 3544.467
# 	 Val. Loss: 90237.833
# Epoch: 15 | Time: 2m 56s
# 	Train Loss: 1873.251
# 	 Val. Loss: 82552.682
# Epoch: 16 | Time: 2m 56s
# 	Train Loss: 1502.687
# 	 Val. Loss: 82617.876
# Epoch: 17 | Time: 2m 57s
# 	Train Loss: 1324.078
# 	 Val. Loss: 79839.580
# Epoch: 18 | Time: 2m 56s
# 	Train Loss: 1465.609
# 	 Val. Loss: 82926.573
# Epoch: 19 | Time: 2m 56s
# 	Train Loss: 1353.785
# 	 Val. Loss: 106690.107
# Epoch: 20 | Time: 2m 56s
# 	Train Loss: 1312.796
# 	 Val. Loss: 77725.721
# Epoch: 21 | Time: 2m 56s
# 	Train Loss: 1386.449
# 	 Val. Loss: 95317.535
# Epoch: 22 | Time: 2m 56s
# 	Train Loss: 1670.762
# 	 Val. Loss: 86260.058
# Epoch: 23 | Time: 2m 57s
# 	Train Loss: 2124.409
# 	 Val. Loss: 79924.965
# Epoch: 24 | Time: 2m 56s
# 	Train Loss: 1810.591
# 	 Val. Loss: 74976.638
# Epoch: 25 | Time: 2m 56s
# 	Train Loss: 1620.579
# 	 Val. Loss: 75947.580
# Epoch: 26 | Time: 2m 56s
# 	Train Loss: 1210.969
# 	 Val. Loss: 72729.879
# Epoch: 27 | Time: 2m 56s
# 	Train Loss: 1141.952
# 	 Val. Loss: 75747.781
# Epoch: 28 | Time: 2m 56s
# 	Train Loss: 1281.850
# 	 Val. Loss: 71859.803
# Epoch: 29 | Time: 2m 57s
# 	Train Loss: 1297.078
# 	 Val. Loss: 82172.990
# Epoch: 30 | Time: 2m 57s
# 	Train Loss: 1927.850
# 	 Val. Loss: 75411.585
# Epoch: 31 | Time: 2m 56s
# 	Train Loss: 1273.479
# 	 Val. Loss: 74261.615
# Epoch: 32 | Time: 2m 56s
# 	Train Loss: 1333.543
# 	 Val. Loss: 73276.774
# Epoch: 33 | Time: 2m 56s
# 	Train Loss: 1115.356
# 	 Val. Loss: 73219.407
# Epoch: 34 | Time: 2m 56s
# 	Train Loss: 1085.714
# 	 Val. Loss: 72950.225
# Epoch: 35 | Time: 2m 56s
# 	Train Loss: 1084.702
# 	 Val. Loss: 72348.546
# Epoch: 36 | Time: 2m 57s
# 	Train Loss: 1157.668
# 	 Val. Loss: 72922.554
# Epoch: 37 | Time: 2m 57s
# 	Train Loss: 1256.509
# 	 Val. Loss: 74630.027
# Epoch: 38 | Time: 2m 56s
# 	Train Loss: 2065.634
# 	 Val. Loss: 75915.489
# Epoch: 39 | Time: 2m 57s
# 	Train Loss: 1875.653
# 	 Val. Loss: 73205.508
# Epoch: 40 | Time: 2m 56s
# 	Train Loss: 1402.078
# 	 Val. Loss: 70353.255
# Epoch: 41 | Time: 2m 57s
# 	Train Loss: 2675.033
# 	 Val. Loss: 77774.478
# Epoch: 42 | Time: 2m 57s
# 	Train Loss: 1424.811
# 	 Val. Loss: 73500.952
# Epoch: 43 | Time: 2m 57s
# 	Train Loss: 1273.435
# 	 Val. Loss: 75064.015
# Epoch: 44 | Time: 2m 57s
# 	Train Loss: 1186.799
# 	 Val. Loss: 73679.990
# Epoch: 45 | Time: 2m 56s
# 	Train Loss: 1190.663
# 	 Val. Loss: 77203.918
# Epoch: 46 | Time: 2m 57s
# 	Train Loss: 1171.998
# 	 Val. Loss: 79616.786
# Epoch: 47 | Time: 2m 57s
# 	Train Loss: 1532.599
# 	 Val. Loss: 76425.478
# Epoch: 48 | Time: 2m 56s
# 	Train Loss: 1186.743
# 	 Val. Loss: 78899.204
# Epoch: 49 | Time: 2m 56s
# 	Train Loss: 1132.783
# 	 Val. Loss: 102046.774
# Epoch: 50 | Time: 2m 56s
# 	Train Loss: 1075.501
# 	 Val. Loss: 80968.284
# Epoch: 51 | Time: 2m 57s
# 	Train Loss: 1322.793
# 	 Val. Loss: 81314.862
# Epoch: 52 | Time: 2m 57s
# 	Train Loss: 1339.963
# 	 Val. Loss: 92529.494
# Epoch: 53 | Time: 2m 57s
# 	Train Loss: 2020.874
# 	 Val. Loss: 82031.077
# Epoch: 54 | Time: 2m 56s
# 	Train Loss: 1571.561
# 	 Val. Loss: 107865.539
# Epoch: 55 | Time: 2m 57s
# 	Train Loss: 1271.840
# 	 Val. Loss: 81966.292
# Epoch: 56 | Time: 2m 56s
# 	Train Loss: 1957.066
# 	 Val. Loss: 98465.753
# Epoch: 57 | Time: 2m 57s
# 	Train Loss: 2574.529
# 	 Val. Loss: 91486.620
# Epoch: 58 | Time: 2m 57s
# 	Train Loss: 1182.118
# 	 Val. Loss: 80038.887
# Epoch: 59 | Time: 2m 57s
# 	Train Loss: 2323.567
# 	 Val. Loss: 70838.837
# Epoch: 60 | Time: 2m 57s
# 	Train Loss: 1219.649
# 	 Val. Loss: 71590.633
# Epoch: 61 | Time: 2m 57s
# 	Train Loss: 1264.511
# 	 Val. Loss: 69560.703
# Epoch: 62 | Time: 2m 57s
# 	Train Loss: 1192.642
# 	 Val. Loss: 71828.211
# Epoch: 63 | Time: 2m 57s
# 	Train Loss: 1022.670
# 	 Val. Loss: 71766.237
# Epoch: 64 | Time: 2m 57s
# 	Train Loss: 1070.566
# 	 Val. Loss: 94853.931
# Epoch: 65 | Time: 2m 56s
# 	Train Loss: 1151.756
# 	 Val. Loss: 70426.106
# Epoch: 66 | Time: 2m 56s
# 	Train Loss: 993.420
# 	 Val. Loss: 71062.347
# Epoch: 67 | Time: 2m 57s
# 	Train Loss: 945.381
# 	 Val. Loss: 74217.964
# Epoch: 68 | Time: 2m 57s
# 	Train Loss: 1333.832
# 	 Val. Loss: 76701.856
# Epoch: 69 | Time: 2m 57s
# 	Train Loss: 1025.381
# 	 Val. Loss: 76944.976
# Epoch: 70 | Time: 2m 56s
# 	Train Loss: 1473.719
# 	 Val. Loss: 78182.836
# Epoch: 71 | Time: 2m 57s
# 	Train Loss: 1044.583
# 	 Val. Loss: 79854.887
# Epoch: 72 | Time: 2m 56s
# 	Train Loss: 1750.649
# 	 Val. Loss: 77436.690
# Epoch: 73 | Time: 2m 57s
# 	Train Loss: 1554.869
# 	 Val. Loss: 77469.536
# Epoch: 74 | Time: 2m 57s
# 	Train Loss: 1223.417
# 	 Val. Loss: 74192.275
# Epoch: 75 | Time: 2m 57s
# 	Train Loss: 1172.141
# 	 Val. Loss: 74915.337
# Epoch: 76 | Time: 2m 56s
# 	Train Loss: 939.603
# 	 Val. Loss: 76835.962
# Epoch: 77 | Time: 2m 57s
# 	Train Loss: 906.270
# 	 Val. Loss: 79196.856
# Epoch: 78 | Time: 2m 57s
# 	Train Loss: 1853.399
# 	 Val. Loss: 82419.865
# Epoch: 79 | Time: 2m 56s
# 	Train Loss: 1072.464
# 	 Val. Loss: 81633.856
# Epoch: 80 | Time: 2m 56s
# 	Train Loss: 2093.131
# 	 Val. Loss: 99071.742
# Epoch: 81 | Time: 2m 56s
# 	Train Loss: 2036.525
# 	 Val. Loss: 92994.290
# Epoch: 82 | Time: 2m 57s
# 	Train Loss: 1151.225
# 	 Val. Loss: 90818.796
# Epoch: 83 | Time: 2m 56s
# 	Train Loss: 1231.831
# 	 Val. Loss: 86317.498
# Epoch: 84 | Time: 2m 57s
# 	Train Loss: 1122.112
# 	 Val. Loss: 80225.442
# Epoch: 85 | Time: 2m 57s
# 	Train Loss: 1261.961
# 	 Val. Loss: 80194.911
# Epoch: 86 | Time: 2m 57s
# 	Train Loss: 1179.038
# 	 Val. Loss: 78238.596
# Epoch: 87 | Time: 2m 57s
# 	Train Loss: 1075.910
# 	 Val. Loss: 75355.666
# Epoch: 88 | Time: 2m 56s
# 	Train Loss: 937.938
# 	 Val. Loss: 75406.280
# Epoch: 89 | Time: 2m 56s
# 	Train Loss: 1040.082
# 	 Val. Loss: 75486.739
# Epoch: 90 | Time: 2m 57s
# 	Train Loss: 1108.082
# 	 Val. Loss: 74909.468
# Epoch: 91 | Time: 2m 57s
# 	Train Loss: 877.481
# 	 Val. Loss: 76846.181
# Epoch: 92 | Time: 2m 57s
# 	Train Loss: 901.492
# 	 Val. Loss: 76891.889
# Epoch: 93 | Time: 2m 57s
# 	Train Loss: 907.986
# 	 Val. Loss: 93874.400
# Epoch: 94 | Time: 2m 56s
# 	Train Loss: 858.526
# 	 Val. Loss: 106022.689
# Epoch: 95 | Time: 2m 57s
# 	Train Loss: 965.944
# 	 Val. Loss: 103722.438
# Epoch: 96 | Time: 2m 56s
# 	Train Loss: 901.354
# 	 Val. Loss: 87916.153
# Epoch: 97 | Time: 2m 57s
# 	Train Loss: 960.419
# 	 Val. Loss: 80411.810
# Epoch: 98 | Time: 2m 57s
# 	Train Loss: 1635.613
# 	 Val. Loss: 75731.976
# Epoch: 99 | Time: 2m 57s
# 	Train Loss: 880.168
# 	 Val. Loss: 76327.158
# Epoch: 100 | Time: 2m 57s
# 	Train Loss: 849.419
# 	 Val. Loss: 78423.071
